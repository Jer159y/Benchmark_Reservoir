# %%
$pip install nengo nengo-gui
# https://notebook.community/ahwillia/RecNetLearn/tutorials/FORCE_Learning
# https://www.nengo.ai/getting-started/
# https://arvoelke.github.io/nengolib-docs/notebooks/examples/full_force_learning.html
